\xe4\x9e\xb9\xff\x00\x1a\x92\x19\xd9r>\xd9\x12t\xeb\x0bn\xf6\xf6\xa6\xd7`\x8c\xd2\xdc\xd0\xd3\xed\x1d$yYC\x06 \x8c?N{}j\xf5\xb5\x9cs\xc72!P\xaew!\'\x1f\x8dd,\x97rF\x1a\rj\xd5e\xc1\xf9\x1a\x13\x81\xf48\xa4\x93\xfbAy\x93T\xb6\xc9]\xa7\xe6+\xc7Z\x9eVW\xb4E\xbb\xe9ma\xb7e\xc8\x92g8Npv\x83\xd7\x15U ...

# %%
# !ls
# Out:
# sample_data  service-account.json  starter.jpg

# %%
path = r'starter.jpg'

# %%
import os, io
from google.cloud import vision
from google.cloud.vision import types

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'service-account.json'

def starter(path):

    client = vision.ImageAnnotatorClient()
 
    if path.startswith('http') or path.startswith('gs:'):
        image = types.Image()
        image.source.image_uri = path
    else:
        with io.open(path, 'rb') as image_file:
            content = image_file.read()
        image = types.Image(content=content)
 
    result = client.text_detection(image=image).text_annotations
 
    return result

# %%
result = starter(path)
result
# Out:
# [locale: "en"
# description: "BUCKINGHAM PALACE\nROAD SW1\nCITY OF WESTMINSTER\n"
# bounding_poly {
#   vertices {
#     x: 107
#     y: 180
#   }
#   vertices {
#     x: 754
#     y: 180
#   }
#   vertices {
#     x: 754
#     y: 335
#   }
#   vertices {
#     x: 107
#     y: 335
#   }
# }
# , description: "BUCKINGHAM"
# bounding_poly {
#   vertices {
#     x: 113
#     y: 180
#   }
#   vertices {
#     x: 538
#     y: 180
#   }
#   vertices {
#     x: 538
#     y: 234
#   }
#   vertices {
#     x: 113
#     y: 234
#   }
# }
# , description: "PALACE"
# bounding_poly {
#   vertices {
#     x: 531
#     y: 183
#   }
#   vertices {
#     x: 754
#     y: 183
#   }
#   vertices {
#     x: 754
#     y: 227
#   }
#   vertices {
#     x: 531
#     y: 227
#   }
# }
# , description: "ROAD"
# bounding_poly {
#   vertices {
#     x: 107
#     y: 239
#   }
#   vertices {
#     x: 286
#     y: 239
#   }
#   vertices {
#     x: 286
#     y: 292
#   }
#   vertices {
#     x: 107
#     y: 292
#   }
# }
# , description: "SW1"
# bounding_poly {
#   vertices {
#     x: 299
#     y: 243
#   }
#   vertices {
#     x: 408
#     y: 243
#   }
#   vertices {
#     x: 408
#     y: 284
#   }
#   vertices {
#     x: 299
#     y: 284
#   }
# }
# , description: "CITY"
# bounding_poly {
#   vertices {
#     x: 115
#     y: 316
#   }
#   vertices {
#     x: 170
#     y: 316
#   }
#   vertices {
#     x: 170
#     y: 335
#   }
#   vertices {
#     x: 115
#     y: 335
#   }
# }
# , description: "OF"
# bounding_poly {
#   vertices {
#     x: 181
#     y: 316
#   }
#   vertices {
#     x: 213
#     y: 316
#   }
#   vertices {
#     x: 213
#     y: 335
#   }
#   vertices {
#     x: 181
#     y: 335
#   }
# }
# , description: "WESTMINSTER"
# bounding_poly {
#   vertices {
#     x: 223
#     y: 316
#   }
#   vertices {
#     x: 403
#     y: 315
#   }
#   vertices {
#     x: 403
#     y: 334
#   }
#   vertices {
#     x: 223
#     y: 335
#   }
# }
# ]

# %%
def get_descriptions(text):
  if not text:
    print('No text found')
  else:
    for t in text:
      print(t.description)

# %%
get_descriptions(result)
# Out:
# BUCKINGHAM PALACE
# ROAD SW1
# CITY OF WESTMINSTER
#
# BUCKINGHAM
# PALACE
# ROAD
# SW1
# CITY
# OF
# WESTMINSTER
