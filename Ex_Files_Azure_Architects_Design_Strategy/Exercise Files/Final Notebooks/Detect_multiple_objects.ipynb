x03\x00\x01\x00\x00\x00\x01\x00\x00\x00\'\x88\x03\x00\x01\x00\x00\x00 \x03\x00\x00\x00\x90\x07\x00\x04\x00\x00\x000230\x03\x90\x02\x00\x14\x00\x00\x00p\x02\x00\x00\x04\x90\x02\x00\x14\x00\x00\x00\x84\x02\x00\x00\x01\x91\x07\x00\x04\x00\x00\x00\x01\x02\x03\x00\x01\x92\n\x00\x01\x00\x00\x00\x98\x02\x00\x00\x02\x92\x05\x00\x01\x00\x00\x00\xa0\x02\x00\x00\x04\x92\n\x00\x01\x00\x00\x00\xa8\x02\x00\x00\x05\x92\x05\x00\x01\x00\x00\x00\xb0\x02\x00\x00\x06\x92\x05\x00\x01\x00\x00\x00\xb8\x02\x00\x00\x07\x92\x03\x00\x01\x00\x00\x00\x02\x00\x00\x00\n\x92\x05\x00\x01\x00\x00\x00\xc0\x02\x00\x00\x11\x92\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x92\x92\x02\x00\x03\x00\x00\x0002\x00\x00\x00\xa0\x07\x00\x04\x00\x00\x000100\t\xa4\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00\n\xa4\x03\x00\x01\x00\x00\x00\x00\x00\x00\x001\xa4\x02\x00\x0b\x00\x00\x00\xd8\x02\x00\x002\xa4\x05\x00\x04\x00\x00\x00\xe4\x02\x00\x004\xa4\x02\x00\x16\x00\x00\x00\x04\x03\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00d\x00\x00\x00\x0e\x00\x00\x00\x05\x00\x00\x002014:03:16 20:29:35\x002014:03:16 20:29:35\x00\xf53\x00\x00\xd2\x07\x00\x00)_\x00\x00\x08 \x00\x00\x00\x00\x00\x00\ ...

# %%
# !ls
# Out:
# multiple-objects.jpg  sample_data  service-account.json

# %%
path = r'multiple-objects.jpg'

# %%
import os, io
from google.cloud import vision
from google.cloud.vision import types

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'service-account.json'

def starter(path):

    client = vision.ImageAnnotatorClient()
 
    if path.startswith('http') or path.startswith('gs:'):
        image = types.Image()
        image.source.image_uri = path
    else:
        with io.open(path, 'rb') as image_file:
            content = image_file.read()
        image = types.Image(content=content)
 
    result = client.object_localization(image=image).localized_object_annotations
 
    return result

# %%
data = starter(path)
data
# Out:
# [mid: "/m/07gql"
# name: "Trumpet"
# score: 0.6994413733482361
# bounding_poly {
#   normalized_vertices {
#     x: 0.0010411972180008888
#     y: 0.056366611272096634
#   }
#   normalized_vertices {
#     x: 0.3858635723590851
#     y: 0.056366611272096634
#   }
#   normalized_vertices {
#     x: 0.3858635723590851
#     y: 0.7729988694190979
#   }
#   normalized_vertices {
#     x: 0.0010411972180008888
#     y: 0.7729988694190979
#   }
# }
# , mid: "/m/07gql"
# name: "Trumpet"
# score: 0.6936535835266113
# bounding_poly {
#   normalized_vertices {
#     x: 0.21642673015594482
#     y: 0.04288901388645172
#   }
#   normalized_vertices {
#     x: 0.7561625838279724
#     y: 0.04288901388645172
#   }
#   normalized_vertices {
#     x: 0.7561625838279724
#     y: 0.7299375534057617
#   }
#   normalized_vertices {
#     x: 0.21642673015594482
#     y: 0.7299375534057617
#   }
# }
# , mid: "/m/01g317"
# name: "Person"
# score: 0.5973871350288391
# bounding_poly {
#   normalized_vertices {
#     x: 0.0002403986145509407
#     y: 0.20201897621154785
#   }
#   normalized_vertices {
#     x: 0.21082715690135956
#     y: 0.20201897621154785
#   }
#   normalized_vertices {
#     x: 0.21082715690135956
#     y: 0.9973958134651184
#   }
#   normalized_vertices {
#     x: 0.0002403986145509407
#     y: 0.9973958134651184
#   }
# }
# , mid: "/m/04szw"
# name: "Musical instrument"
# score: 0.5239996314048767
# bounding_poly {
#   normalized_vertices {
#     x: 0.02327764593064785
#     y: 0.02225307933986187
#   }
#   normalized_vertices {
#     x: 0.479103684425354
#     y: 0.02225307933986187
#   }
#   normalized_vertices {
#     x: 0.479103684425354
#     y: 0.5102805495262146
#   }
#   normalized_vertices {
#     x: 0.02327764593064785
#     y: 0.5102805495262146
#   }
# }
# ]

# %%
def get_objects(data):
  if not data:
    print('No objects detected')
  else:
    for d in data:
      print('Name : {}      Score : {}'.format(d.name, d.score))

# %%
get_objects(data)
# Out:
# Name : Trumpet      Score : 0.6994413733482361
# Name : Trumpet      Score : 0.6936535835266113
# Name : Person      Score : 0.5973871350288391
# Name : Musical instrument      Score : 0.5239996314048767
